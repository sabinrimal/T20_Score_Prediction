# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data\\1001349.yaml',
#  'data\\1001351.yaml',
#  'data\\1001353.yaml',
#  'data\\1004729.yaml',
#  'data\\1007655.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1267/1267 [30:43<00:00,  1.45s/it]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# ...

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings  info.balls_per_over  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                    6
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                    6
# ..                                                ...                  ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                    6
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                    6
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
#
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male    1267
# Name: info.gender, dtype: int64

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    1267
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    1264
# 50       3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'info.overs'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
final_df
# Out:
#                                               innings  info.balls_per_over  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                    6
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                    6
# ..                                                ...                  ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                    6
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                    6
# 0   [{'1st innings': {'team': 'Australia', 'delive...                    6
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
#
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    mid = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            mid.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'mid':mid,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#       mid                   teams batting_team  ball          batsman  \
# 0       2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1       2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2       2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3       2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4       2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..    ...                     ...          ...   ...              ...
# 121  1265  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122  1265  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123  1265  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124  1265  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125  1265  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#       mid                   teams batting_team  ball          batsman  \
# 0       2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1       2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2       2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3       2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4       2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..    ...                     ...          ...   ...              ...
# 121  1265  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122  1265  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123  1265  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124  1265  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125  1265  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#       mid batting_team  ball          batsman      bowler  runs  \
# 0       2    Australia   0.1         AJ Finch  SL Malinga     0
# 1       2    Australia   0.2         AJ Finch  SL Malinga     0
# 2       2    Australia   0.3         AJ Finch  SL Malinga     1
# 3       2    Australia   0.4        M Klinger  SL Malinga     2
# 4       2    Australia   0.5        M Klinger  SL Malinga     0
# ..    ...          ...   ...              ...         ...   ...
# 121  1265    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122  1265    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123  1265    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124  1265    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125  1265    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania',
#        'Luxembourg', 'Austria', 'Czech Republic', 'Greece', 'Serbia',
#        'Malta', 'France', 'Sweden', 'Rwanda', 'Finland', 'Hungary',
#        'Estonia', 'Cyprus', 'Switzerland', 'Swaziland', 'Seychelles',
# ...

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#       mid batting_team  ball          batsman      bowler  runs  \
# 0       2    Australia   0.1         AJ Finch  SL Malinga     0
# 1       2    Australia   0.2         AJ Finch  SL Malinga     0
# 2       2    Australia   0.3         AJ Finch  SL Malinga     1
# 3       2    Australia   0.4        M Klinger  SL Malinga     2
# 4       2    Australia   0.5        M Klinger  SL Malinga     0
# ..    ...          ...   ...              ...         ...   ...
# 121  1265    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122  1265    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123  1265    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124  1265    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125  1265    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
delivery_df.to_csv('t20.csv')

# %%
output = delivery_df[['mid','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#       mid batting_team bowling_team  ball  runs player_dismissed     city  \
# 0       2    Australia    Sri Lanka   0.1     0                0      NaN
# 1       2    Australia    Sri Lanka   0.2     0                0      NaN
# 2       2    Australia    Sri Lanka   0.3     1                0      NaN
# 3       2    Australia    Sri Lanka   0.4     2                0      NaN
# 4       2    Australia    Sri Lanka   0.5     0                0      NaN
# ..    ...          ...          ...   ...   ...              ...      ...
# 121  1265    Sri Lanka    Australia  19.3     1                0  Colombo
# 122  1265    Sri Lanka    Australia  19.4     0                0  Colombo
# 123  1265    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124  1265    Sri Lanka    Australia  19.6     2                0  Colombo
# 125  1265    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df.isnull().sum()
# Out:
# mid                    0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8543
# venue                  0
# dtype: int64

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2964
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# mid                 0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#       mid batting_team bowling_team  ball  runs player_dismissed       city
# 0       2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1       2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2       2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3       2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4       2    Australia    Sri Lanka   0.5     0                0  Melbourne
# ..    ...          ...          ...   ...   ...              ...        ...
# 121  1265    Sri Lanka    Australia  19.3     1                0    Colombo
# 122  1265    Sri Lanka    Australia  19.4     0                0    Colombo
# 123  1265    Sri Lanka    Australia  19.5     0      DM de Silva    Colombo
# 124  1265    Sri Lanka    Australia  19.6     2                0    Colombo
# 125  1265    Sri Lanka    Australia  19.7     1                0    Colombo
#
# [74383 rows x 7 columns]

# %%
df['city'].value_counts()
# Out:
# Colombo          4816
# Dubai            4149
# Johannesburg     3578
# Mirpur           3297
# Auckland         2655
#                  ...
# Victoria          123
# Dharamsala        122
# Potchefstroom     122
# Carrara            64
# Bridgetown         56
# Name: city, Length: 92, dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 400].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#       mid batting_team bowling_team  ball  runs player_dismissed       city
# 0       2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1       2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2       2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3       2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4       2    Australia    Sri Lanka   0.5     0                0  Melbourne
# ..    ...          ...          ...   ...   ...              ...        ...
# 121  1265    Sri Lanka    Australia  19.3     1                0    Colombo
# 122  1265    Sri Lanka    Australia  19.4     0                0    Colombo
# 123  1265    Sri Lanka    Australia  19.5     0      DM de Silva    Colombo
# 124  1265    Sri Lanka    Australia  19.6     2                0    Colombo
# 125  1265    Sri Lanka    Australia  19.7     1                0    Colombo
#
# [64011 rows x 7 columns]

# %%
df['current_score'] = df.groupby('mid').cumsum()['runs']
# Out:
# C:\Users\Anish\AppData\Local\Temp/ipykernel_8248/115409903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('mid').cumsum()['runs']

# %%
df
# Out:
#       mid batting_team bowling_team  ball  runs player_dismissed       city  \
# 0       2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1       2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2       2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3       2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4       2    Australia    Sri Lanka   0.5     0                0  Melbourne
# ..    ...          ...          ...   ...   ...              ...        ...
# 121  1265    Sri Lanka    Australia  19.3     1                0    Colombo
# 122  1265    Sri Lanka    Australia  19.4     0                0    Colombo
# 123  1265    Sri Lanka    Australia  19.5     0      DM de Silva    Colombo
# 124  1265    Sri Lanka    Australia  19.6     2                0    Colombo
# 125  1265    Sri Lanka    Australia  19.7     1                0    Colombo
#
#      current_score
# 0                0
# ...

# %%
df.descirbe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8248/676111493.py in <module>
# ----> 1 df.descirbe()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'descirbe'

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'over'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#       mid batting_team bowling_team  ball  runs player_dismissed       city  \
# 0       2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1       2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2       2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3       2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4       2    Australia    Sri Lanka   0.5     0                0  Melbourne
# ..    ...          ...          ...   ...   ...              ...        ...
# 121  1265    Sri Lanka    Australia  19.3     1                0    Colombo
# 122  1265    Sri Lanka    Australia  19.4     0                0    Colombo
# 123  1265    Sri Lanka    Australia  19.5     0      DM de Silva    Colombo
# 124  1265    Sri Lanka    Australia  19.6     2                0    Colombo
# 125  1265    Sri Lanka    Australia  19.7     1                0    Colombo
#
#      current_score
# 0                0
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\Anish\AppData\Local\Temp/ipykernel_8248/1757844946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\Anish\AppData\Local\Temp/ipykernel_8248/1757844946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#       mid batting_team bowling_team  ball  runs player_dismissed       city  \
# 0       2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1       2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2       2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3       2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4       2    Australia    Sri Lanka   0.5     0                0  Melbourne
# ..    ...          ...          ...   ...   ...              ...        ...
# 121  1265    Sri Lanka    Australia  19.3     1                0    Colombo
# 122  1265    Sri Lanka    Australia  19.4     0                0    Colombo
# 123  1265    Sri Lanka    Australia  19.5     0      DM de Silva    Colombo
# 124  1265    Sri Lanka    Australia  19.6     2                0    Colombo
# 125  1265    Sri Lanka    Australia  19.7     1                0    Colombo
#
#      current_score over ball_no
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'balls_bowled'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('mid').cumsum()['player_dismissed']
df['wickeets'] = df['palyer_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Anish\AppData\Local\Temp/ipykernel_8248/2444720787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\Anish\AppData\Local\Temp/ipykernel_8248/2444720787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\Anish\AppData\Local\Temp/ipykernel_8248/2444720787.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       mid batting_team bowling_team  ball  runs  player_dismissed       city  \
# 0       2    Australia    Sri Lanka   0.1     0                 1  Melbourne
# 1       2    Australia    Sri Lanka   0.2     0                 2  Melbourne
# 2       2    Australia    Sri Lanka   0.3     1                 3  Melbourne
# 3       2    Australia    Sri Lanka   0.4     2                 4  Melbourne
# 4       2    Australia    Sri Lanka   0.5     0                 5  Melbourne
# ..    ...          ...          ...   ...   ...               ...        ...
# 121  1265    Sri Lanka    Australia  19.3     1               122    Colombo
# 122  1265    Sri Lanka    Australia  19.4     0               123    Colombo
# 123  1265    Sri Lanka    Australia  19.5     0               124    Colombo
# 124  1265    Sri Lanka    Australia  19.6     2               125    Colombo
# 125  1265    Sri Lanka    Australia  19.7     1               126    Colombo
#
#      current_score over ball_no
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'balls_bowled'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121      1265    Sri Lanka    Australia  19.3     1                 8
# 122      1265    Sri Lanka    Australia  19.4     0                 8
# 123      1265    Sri Lanka    Australia  19.5     0                 9
# 124      1265    Sri Lanka    Australia  19.6     2                 9
# 125      1265    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\Anish\AppData\Local\Temp/ipykernel_1456/1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df.to_csv('t20df.csv')

# %%
last_five
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  42.0,
#  43.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  39.0,
#  38.0,
#  39.0,
#  38.0,
#  39.0,
#  40.0,
#  37.0,
#  41.0,
#  42.0,
#  42.0,
#  44.0,
#  44.0,
#  40.0,
#  39.0,
#  37.0,
#  35.0,
#  31.0,
#  27.0,
#  26.0,
#  31.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  31.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  39.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  44.0,
#  39.0,
#  43.0,
#  45.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  53.0,
#  53.0,
#  53.0,
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['match_id','batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#        match_id batting_team bowling_team       city  current_score  \
# 0             2    Australia    Sri Lanka  Melbourne              0
# 1             2    Australia    Sri Lanka  Melbourne              0
# 2             2    Australia    Sri Lanka  Melbourne              1
# 3             2    Australia    Sri Lanka  Melbourne              3
# 4             2    Australia    Sri Lanka  Melbourne              3
# ...         ...          ...          ...        ...            ...
# 61433      1265    Sri Lanka    Australia    Colombo            125
# 61434      1265    Sri Lanka    Australia    Colombo            125
# 61435      1265    Sri Lanka    Australia    Colombo            125
# 61436      1265    Sri Lanka    Australia    Colombo            127
# 61437      1265    Sri Lanka    Australia    Colombo            128
#
#        balls_left  wickets_left       crr  last_five  runs_x
# 0             119            10  0.000000        NaN     168
# ...

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df.to_csv('t20feature.csv')

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 45413  South Africa        India  Johannesburg            131          36
# 30957     Australia    Sri Lanka    Nottingham            124          18
# 33533  South Africa      England     Centurion            179          36
# 10043   West Indies      England    Gros Islet            102          32
# 37941     Sri Lanka        India        Nagpur            117          46
# ...             ...          ...           ...            ...         ...
# 48246       England    Australia     Melbourne            127           2
# 4298        England        India    Manchester             71          68
# 8250     Bangladesh  West Indies    Lauderhill             78          74
# 37216   New Zealand    Australia    Wellington             73          39
# 55973     Australia        India        Sydney            148          27
#
#        wickets_left        crr  last_five  runs_x
# ...
